# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./../datasets/December_2021/reveal_story_dataset.csv')

# %%
df.head()
# Out:
#    index        NCTId TrialAcronym  \
# 0    284  NCT02008396          NaN
# 1    176  NCT05030129          NaN
# 2     44  NCT04895215          NaN
# 3     17  NCT01300923          NaN
# 4    204  NCT02998151          LAM
#
#                                  ArmGroupDescription  \
# 0  Subjects will receive inactive placebo during ...
# 1  Ergoloid mesylates (EM) 1 mg three times daily...
# 2                                                NaN
# 3  The maximum dose of acamprosate to be used in ...
# 4                                       Placebo pill
#
#                             ArmGroupInterventionName  \
# 0  Drug: Placebo|Behavioral: Psychotherapy|Drug: ...
# 1  Dietary Supplement: 5-Hydroxytryptophan / Vita...
# 2          Drug: AB-2004|Drug: AB-2004|Drug: Placebo
# 3                                  Drug: Acamprosate
# 4  Drug: Placebo|Drug: Acamprosate|Drug: Lovastat...
#
#                                         DrugsTested  \
# 0          3,4-Methylenedioxymethamphetamine (MDMA)
# 1  5-Hydroxytryptophan|Vitamin B6|Ergoloid Mesylate
# 2                                           AB-2004
# 3                                       Acamprosate
# 4                Acamprosate|Lovastatin|Minocycline
#
#                                       OtherDrugNames  \
# 0                                            Ecstasy
# 1            Oxitriptan|Pyridoxine|Dihydroergotoxine
# 2                                               None
# 3                                            Campral
# 4  Campral|Altoprev,Mevacor|Cleeravue-M, Dynacin,...
#
#                                        DrugMechanism  \
# 0  MDMA is a synthetic serotonergic agonist that ...
# 1  5-Hydroxytryptophan is a compound that increas...
# 2  AB-2004 is an experimental compound designed t...
# 3  Acamprosate is a structural analogue of gamma-...
# 4  Acamprosate is a structural analogue of gamma-...
#
#                                              Sources PreviouslyApproved  ...  \
# 0  https://www.spectrumnews.org/news/ecstasy-ingr...                 No  ...
# 1  https://www.spectrumnews.org/opinion/genetic-r...         No|Yes|Yes  ...
# 2  https://www.nature.com/articles/d43747-020-011...                 No  ...
# 3  https://www.spectrumnews.org/news/finding-a-pa...                Yes  ...
# 4  https://www.spectrumnews.org/news/finding-a-pa...        Yes|Yes|Yes  ...
#
#   StatusVerifiedDate             StdAge StudyFirstPostDate  \
# 0             19-Jun  Adult|Older Adult          11-Dec-13
# 1             21-Aug              Adult           1-Sep-21
# 2             21-Oct              Child          20-May-21
# 3             19-Jul              Child          23-Feb-11
# 4             20-Mar        Child|Adult          20-Dec-16
#
#   StudyFirstPostDateType StudyFirstSubmitDate StudyFirstSubmitQCDate  \
# 0               Estimate                  NaN               6-Dec-13
# 1                 Actual             5-Aug-21              27-Aug-21
# 2                 Actual            17-May-21              17-May-21
# 3               Estimate            25-Aug-10              18-Feb-11
# 4               Estimate             1-Dec-16              15-Dec-16
#
#   StudyPopulation       StudyType VersionHolder WhyStopped
# 0             NaN  Interventional     15-Oct-21        NaN
# 1             NaN  Interventional     15-Oct-21        NaN
# 2             NaN  Interventional      9-Nov-21        NaN
# 3             NaN  Interventional     15-Oct-21        NaN
# 4             NaN  Interventional     15-Oct-21        NaN
#
# [5 rows x 147 columns]

# %%
df.describe(include = 'all')
# Out:
#               index        NCTId TrialAcronym  \
# count    314.000000          314           89
# unique          NaN          314           84
# top             NaN  NCT02677051        CM-AT
# freq            NaN            1            2
# mean     161.302548          NaN          NaN
# std      114.339697          NaN          NaN
# min        1.000000          NaN          NaN
# 25%       79.500000          NaN          NaN
# 50%      158.500000          NaN          NaN
# 75%      235.750000          NaN          NaN
# max     1401.000000          NaN          NaN
#
#                                       ArmGroupDescription  \
# count                                                 255
# unique                                                250
# top     ANAVEX2-73 liquid oral solution|Placebo liquid...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        ArmGroupInterventionName DrugsTested OtherDrugNames  \
# count                       298         314            312
# unique                      261         134            118
# top          Drug: Aripiprazole    Oxytocin           None
# freq                          6          22             25
# mean                        NaN         NaN            NaN
# std                         NaN         NaN            NaN
# min                         NaN         NaN            NaN
# 25%                         NaN         NaN            NaN
# 50%                         NaN         NaN            NaN
# 75%                         NaN         NaN            NaN
# max                         NaN         NaN            NaN
#
#                                             DrugMechanism  \
# count                                                  93
# unique                                                 19
# top     This second-generation antipsychotic drug anta...
# freq                                                   16
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                   Sources PreviouslyApproved  \
# count                                                 126                137
# unique                                                 23                  5
# top     https://www.spectrumnews.org/opinion/how-to-im...                Yes
# freq                                                   19                102
# mean                                                  NaN                NaN
# std                                                   NaN                NaN
# min                                                   NaN                NaN
# 25%                                                   NaN                NaN
# 50%                                                   NaN                NaN
# 75%                                                   NaN                NaN
# max                                                   NaN                NaN
#
#         ... StatusVerifiedDate StdAge StudyFirstPostDate  \
# count   ...                313    313                313
# unique  ...                119      5                289
# top     ...             21-Sep  Child          21-Sep-05
# freq    ...                 20    175                  4
# mean    ...                NaN    NaN                NaN
# std     ...                NaN    NaN                NaN
# min     ...                NaN    NaN                NaN
# 25%     ...                NaN    NaN                NaN
# 50%     ...                NaN    NaN                NaN
# 75%     ...                NaN    NaN                NaN
# max     ...                NaN    NaN                NaN
#
#        StudyFirstPostDateType StudyFirstSubmitDate StudyFirstSubmitQCDate  \
# count                     313                  312                    313
# unique                      2                  282                    289
# top                  Estimate            13-Sep-05              13-Sep-05
# freq                      220                    5                      5
# mean                      NaN                  NaN                    NaN
# std                       NaN                  NaN                    NaN
# min                       NaN                  NaN                    NaN
# 25%                       NaN                  NaN                    NaN
# 50%                       NaN                  NaN                    NaN
# 75%                       NaN                  NaN                    NaN
# max                       NaN                  NaN                    NaN
#
#        StudyPopulation       StudyType VersionHolder  \
# count              0.0             313           313
# unique             NaN               1             2
# top                NaN  Interventional     15-Oct-21
# freq               NaN             313           303
# mean               NaN             NaN           NaN
# std                NaN             NaN           NaN
# min                NaN             NaN           NaN
# 25%                NaN             NaN           NaN
# 50%                NaN             NaN           NaN
# 75%                NaN             NaN           NaN
# max                NaN             NaN           NaN
#
#                                                WhyStopped
# count                                                  33
# unique                                                 33
# top     Study terminated due to COVID-19 pandemic and ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
# [11 rows x 147 columns]

# %% [markdown]
# ### Questions to Answer

# %% [markdown]
# 1) How many trials were terminated, and for what reasons?
#
# 2) What is the most common drug tested, and the second, and the third most common?
#
# 3) How many studies have actually posted results?
#
# 4) What fraction of studies that have been completed have posted results?
#
# 5) What are the most common conditions, and in what fractions?
#
# 6) What fraction of drugs in clinical trials have been approved for another condition?
#
# 7) What are the commonly occuring 'combined modality' types? Comment specifically on those trials.
#
# 8) What is the earliest trial? The latest trial?
#
# 9) Put together descriptive statistics on the 'Lead Author Country'.
#
# 10) Who sponsors most studies? Industry or academia?
#
# 11) What are the ranges of minimum and maximum ages?

# %% [markdown]
# ## #1

# %%
len(df)
# Out:
# 314

# %%
stopped_trials = df['WhyStopped'].value_counts()

# %%
len(stopped_trials)
# Out:
# 33

# %%
33/314
# Out:
# 0.10509554140127389

# %%
stopped_trials
# Out:
# Study terminated due to COVID-19 pandemic and recruitment challenges in parent study                                                                               1
# Failure to recruit                                                                                                                                                 1
# too few subjects enrolled                                                                                                                                          1
# the recently feasibility study shows that the number of patients is insufficient in the centers                                                                    1
# This study was halted prior to enrolling.                                                                                                                          1
# Study treatment AFQ056 failed to demonstrate efficacy in the adult patient with Fragile X Syndrome in 2 other clinical studies (CAFQ056B2214 and CAFQ056A2212)     1
# Study terminated due to enrollment challenges during COVID-19 pandemic.                                                                                            1
# Well tolerated but failed to demonstrate significant activity. So it did not meet its primary endpoint or key secondary endpoints.                                 1
# Temporarily stopped due to COVID-19 pandemic.                                                                                                                      1
# Non-compliance                                                                                                                                                     1
# Withdrawn for problem of logistics with the associated laboratories                                                                                                1
# No eligible patients were enrolled                                                                                                                                 1
# Most of our patients had no willingness to participate in the survey                                                                                               1
# This study was withdrawn due to competing research interests and slow recruitment.                                                                                 1
# The study did not demonstrate evidence of efficacy on the primary or secondary efficacy variables                                                                  1
# Due to a change in the research priorities of the principal investigator in combination with low subject interest.                                                 1
# Study was not initiated it was decided to cancel this study                                                                                                        1
# all active subjects were rolled into study 209AS209/NCT01706523                                                                                                    1
# Low recruitment                                                                                                                                                    1
# The study treatment failed to demonstrate efficacy in target population in two other clinical studies (CAFQ056B2214 and CAFQ056A2212).                             1
# pending further evaluation                                                                                                                                         1
# lack of funding                                                                                                                                                    1
# Pharmaceutical and financial difficulties                                                                                                                          1
# The 24-week analysis indicated no clinical or statistical benefit for the primary endpoint for the overall study population. No new safety concerns identified.    1
# Was not possible to enroll sufficient number of subjects to draw any worthwhile conclusions from the study.                                                        1
# all active subjects rolled into 209FX303/NCT01013480                                                                                                               1
# Unsuccessful in recruiting appropriate subjects.                                                                                                                   1
# A futility analysis assessed that the study is highly unlikely to meet the pre-defined primary objective of the study. No new safety concerns were identified.     1
# Study changed to a placebo controlled trial of dextromethorphan                                                                                                    1
# The study was terminated due to enrollment challenges and the COVID-19 pandemic.                                                                                   1
# The study stopped recruitment of new participants due to COVID. A substudy was developed with adaptations to the main design.                                      1
# Terminated because primary efficacy parameter failed to demonstrate statistically significant difference between memantine and placebo in controlled trials        1
# Study not started                                                                                                                                                  1
# Name: WhyStopped, dtype: int64

# %% [markdown]
# ## #2

# %%
druglist = df['DrugsTested'].value_counts()
druglist
# Out:
# Oxytocin                            22
# Aripiprazole                        16
# Cannabidiol                         14
# Risperidone                         11
# Everolimus                          11
#                                     ..
# Vitamin D|Vitamin E                  1
# Ketamine|Dexmedetomidine             1
# Recombinant human growth hormone     1
# Rett-T                               1
# Amitriptyline                        1
# Name: DrugsTested, Length: 134, dtype: int64

# %% [markdown]
# Oxytocin is the most frequently tested drug, with 22 trials. Aripiprazole has 16 trials, and cannabidiol is in third with 14 trials. Fascinating!

# %% [markdown]
# ## #3

# %%
postedresults = df['ResultsFirstPostDateType'].value_counts()

# %%
postedresults
# Out:
# Actual                     63
# Estimate                   47
# U.S. FDA Grant/Contract     1
# Name: ResultsFirstPostDateType, dtype: int64

# %%
63 / len(df)
# Out:
# 0.20063694267515925

# %% [markdown]
# ## #4

# %%
conditions = df['Condition'].value_counts()

# %%
conditions
# Out:
# Autism                                         185
# Fragile X syndrome                              39
# Tuberous sclerosis complex                      27
# Rett syndrome                                   24
# Angelman syndrome                                6
# Antipsychotic-usage weight gain                  6
# Phelan-McDermid syndrome                         5
# Tuberous sclerosis complex-related tumors        4
# Autism with ADHD                                 4
# Tuberous sclerosis complex-related seizures      3
# Autism-related irritability                      3
# Williams syndrome                                2
# ADHD with autism                                 2
# Autism-related sleep disorder                    1
# Velocardiofacial syndrome                        1
# 15q duplication syndrome                         1
# Autism-related anxiety                           1
# Name: Condition, dtype: int64

# %%
27/len(df)
# Out:
# 0.08598726114649681

# %% [markdown]
# ## Lead Sponsor analysis

# %%
leadsponsors = df['LeadSponsorClass'].value_counts()

# %%
leadsponsors
# Out:
# Academia                         183
# Industry                         104
# Other                             13
# National Institutes of Health      9
# Individual                         3
# Government                         2
# Name: LeadSponsorClass, dtype: int64

# %%
183 / len(df)
# Out:
# 0.5828025477707006

# %%
countries = df['LeadSponsorCountry'].value_counts()

# %%
countries
# Out:
# United States     207
# Canada             18
# Switzerland        16
# United Kingdom     12
# Japan              12
# France             12
# Israel              8
# Australia           5
# China               4
# Spain               4
# Egypt               3
# Belgium             3
# Italy               1
# South Korea         1
# Brazil              1
# New Zealand         1
# Poland              1
# Netherlands         1
# Taiwan              1
# Pakistan            1
# Name: LeadSponsorCountry, dtype: int64
