# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./datasets/November_2021/20211109_drug_trials_filtered.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  index  Rank  Acronym  \
# 0           5      5     6  Lisphem
# 1          13     13    14      NaN
# 2          28     28    29   Autism
# 3          39     39    40      NaN
# 4          41     41    42      NaN
#
#                                  ArmGroupDescription  \
# 0  Li+ is an FDA (NDA: 016834) and ANSM (AMM 3400...
# 1  intranasal ketamine and dexmedetomidine was tr...
# 2  15 mg/kg oral solution three times per day, ma...
# 3  Participants in the placebo arm will receive p...
# 4  Patients with Phelan-McDermid syndrome receive...
#
#                             ArmGroupInterventionName  \
# 0              Drug: Lithium Carbonate|Drug: Placebo
# 1  Drug: ketamine and dexmedetomidine|Drug: ketam...
# 2                                      Drug: EPI-743
# 3                     Drug: Memantine|Other: Placebo
# 4             Drug: Recombinant human Growth hormone
#
#                                        ArmGroupLabel  \
# 0                                    Lithium|Placebo
# 1  ketamine and dexmedetomidine group|ketamine gr...
# 2                                            EPI-743
# 3                    Memantine|Placebo|Control Group
# 4                           Phelan-McDermid syndrome
#
#                                       ArmGroupType  \
# 0                  Experimental|Placebo Comparator
# 1     Experimental|Experimental|Placebo Comparator
# 2                                     Experimental
# 3  Experimental|Placebo Comparator|No Intervention
# 4                                     Experimental
#
#                                         BriefSummary  \
# 0  There is currently no treatment for the body s...
# 1  Autism spectrum disorder (ASD) is a life-long ...
# 2  The investigators hypothesize that EPI-743 may...
# 3  This study is a 12-week, randomized-controlled...
# 4  Phelan McDermid syndrome (PMS) is a rare genet...
#
#                                           BriefTitle  ...       StdAge  \
# 0  Effect of Lithium in Patients With Autism Spec...  ...  Child|Adult
# 1  Intranasal Ketamine With Dexmedetomidine for t...  ...        Child
# 2  An Exploratory Open Label Study of EPI-743 (Vi...  ...        Child
# 3  Behavioral and Neural Response to Memantine in...  ...        Child
# 4  Growth Hormone Treatment in Children With Phel...  ...        Child
#
#   StudyFirstPostDate StudyFirstPostDateType StudyFirstSubmitDate  \
# 0  November 10, 2020                 Actual     November 5, 2020
# 1  February 15, 2018                 Actual     January 28, 2018
# 2    August 27, 2014               Estimate      August 21, 2014
# 3   October 30, 2013               Estimate     October 24, 2013
# 4       July 1, 2019                 Actual        June 27, 2019
#
#   StudyFirstSubmitQCDate StudyPopulation       StudyType      VersionHolder  \
# 0       November 9, 2020             NaN  Interventional  November 09, 2021
# 1       February 9, 2018             NaN  Interventional  November 09, 2021
# 2        August 25, 2014             NaN  Interventional  November 09, 2021
# 3       October 29, 2013             NaN  Interventional  November 09, 2021
# 4          June 27, 2019             NaN  Interventional  November 09, 2021
#
#                                   WhyStopped Placebo
# 0                                        NaN     Yes
# 1                                        NaN      No
# 2  This study was halted prior to enrolling.      No
# 3                                        NaN     Yes
# 4                                        NaN      No
#
# [5 rows x 160 columns]

# %%
df.describe(include = 'all')
# Out:
#          Unnamed: 0       index         Rank       Acronym  \
# count    314.000000  314.000000   314.000000            88
# unique          NaN         NaN          NaN            84
# top             NaN         NaN          NaN  Omega Heroes
# freq            NaN         NaN          NaN             2
# mean     755.197452  439.910828   756.197452           NaN
# std      386.835923  307.747020   386.835923           NaN
# min        5.000000    0.000000     6.000000           NaN
# 25%      473.000000  155.000000   474.000000           NaN
# 50%      788.500000  396.000000   789.500000           NaN
# 75%     1063.000000  712.750000  1064.000000           NaN
# max     1648.000000  998.000000  1649.000000           NaN
#
#                                       ArmGroupDescription  \
# count                                                 255
# unique                                                250
# top     NNZ-2591 oral solution (50mg/mL) to be adminis...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        ArmGroupInterventionName ArmGroupLabel  \
# count                       297           297
# unique                      261           258
# top          Drug: Aripiprazole           1|2
# freq                          6             6
# mean                        NaN           NaN
# std                         NaN           NaN
# min                         NaN           NaN
# 25%                         NaN           NaN
# 50%                         NaN           NaN
# 75%                         NaN           NaN
# max                         NaN           NaN
#
#                            ArmGroupType  \
# count                               297
# unique                               37
# top     Experimental|Placebo Comparator
# freq                                 90
# mean                                NaN
# std                                 NaN
# min                                 NaN
# 25%                                 NaN
# 50%                                 NaN
# 75%                                 NaN
# max                                 NaN
#
#                                              BriefSummary  \
# count                                                 314
# unique                                                313
# top     This Phase IIb study is designed to assess whe...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                         BriefTitle  ... StdAge  \
# count                                          314  ...    314
# unique                                         312  ...      5
# top     Intranasal Oxytocin and Learning in Autism  ...  Child
# freq                                             2  ...    175
# mean                                           NaN  ...    NaN
# std                                            NaN  ...    NaN
# min                                            NaN  ...    NaN
# 25%                                            NaN  ...    NaN
# 50%                                            NaN  ...    NaN
# 75%                                            NaN  ...    NaN
# max                                            NaN  ...    NaN
#
#         StudyFirstPostDate StudyFirstPostDateType StudyFirstSubmitDate  \
# count                  314                    314                  314
# unique                 290                      2                  284
# top     September 21, 2005               Estimate   September 13, 2005
# freq                     4                    221                    5
# mean                   NaN                    NaN                  NaN
# std                    NaN                    NaN                  NaN
# min                    NaN                    NaN                  NaN
# 25%                    NaN                    NaN                  NaN
# 50%                    NaN                    NaN                  NaN
# 75%                    NaN                    NaN                  NaN
# max                    NaN                    NaN                  NaN
#
#        StudyFirstSubmitQCDate StudyPopulation       StudyType  \
# count                     314             0.0             314
# unique                    290             NaN               1
# top        September 13, 2005             NaN  Interventional
# freq                        5             NaN             314
# mean                      NaN             NaN             NaN
# std                       NaN             NaN             NaN
# min                       NaN             NaN             NaN
# 25%                       NaN             NaN             NaN
# 50%                       NaN             NaN             NaN
# 75%                       NaN             NaN             NaN
# max                       NaN             NaN             NaN
#
#             VersionHolder                                         WhyStopped  \
# count                 314                                                 33
# unique                  1                                                 33
# top     November 09, 2021  Study terminated due to enrollment challenges ...
# freq                  314                                                  1
# mean                  NaN                                                NaN
# std                   NaN                                                NaN
# min                   NaN                                                NaN
# 25%                   NaN                                                NaN
# 50%                   NaN                                                NaN
# 75%                   NaN                                                NaN
# max                   NaN                                                NaN
#
#        Placebo
# count      314
# unique       2
# top        Yes
# freq       165
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN
#
# [11 rows x 160 columns]

# %% [markdown]
# ### Questions to Answer

# %% [markdown]
# 1) How many trials were terminated, and for what reasons?
#
# 2) What is the most common drug tested, and the second, and the third most common?
#
# 3) How many studies have actually posted results?
#
# 4) What fraction of studies that have been completed have posted results?
#
# 5) What are the most common conditions, and in what fractions?
#
# 6) What fraction of drugs in clinical trials have been approved for another condition?
#
# 7) What are the commonly occuring 'combined modality' types? Comment specifically on those trials.
#
# 8) What is the earliest trial? The latest trial?
#
# 9) Put together descriptive statistics on the 'Lead Author Country'.
#
# 10) Who sponsors most studies? Industry or academia?
#
# 11) What are the ranges of minimum and maximum ages?
